# %%
import sys
sys.path.append("..")

# %%
import sys
print(sys.path)
# Out:
# ['C:\\laragon\\bin\\python\\python-3.13\\python313.zip', 'C:\\laragon\\bin\\python\\python-3.13\\DLLs', 'C:\\laragon\\bin\\python\\python-3.13\\Lib', 'C:\\laragon\\bin\\python\\python-3.13', 'C:\\Users\\safiy\\Desktop\\prep-ia-salma\\.venv', '', 'C:\\Users\\safiy\\Desktop\\prep-ia-salma\\.venv\\Lib\\site-packages', '..']

# %%
from src.utils import load_csv, summarize

# %%
records = load_csv("../data/sample.csv")

print(records)
print()
print(summarize(records))
# Out:
# [{'id': 1, 'name': 'Ali', 'age': 20, 'score': 14.0}, {'id': 2, 'name': 'Sara', 'age': 22, 'score': 18.0}, {'id': 3, 'name': 'Omar', 'age': 21, 'score': 9.0}, {'id': 4, 'name': 'Imane', 'age': 23, 'score': 16.0}, {'id': 5, 'name': 'Youssef', 'age': 20, 'score': 7.0}, {'id': 6, 'name': 'Salma', 'age': 22, 'score': 15.0}, {'id': 7, 'name': 'Nadia', 'age': 24, 'score': 11.0}, {'id': 8, 'name': 'Amine', 'age': 21, 'score': 13.0}, {'id': 9, 'name': 'Karim', 'age': 23, 'score': 8.0}, {'id': 10, 'name': 'Lina', 'age': 20, 'score': 17.0}]
#
# {'count': 10, 'avg_score': 12.8, 'max_score': 18.0, 'min_score': 7.0}

# %% [markdown]
# main.py est le point d'entrée principal d'un programme Python.
# Il s'exécute entièrement lorsqu'on lance la commande python main.py.
#
# Un notebook Jupyter permet d'exécuter le code cellule par cellule.
# On peut importer des fonctions depuis des modules Python et les tester
# interactivement sans exécuter tout le programme.
#
# Le notebook est utilisé pour l'analyse, l'expérimentation et la visualisation,
# tandis que main.py sert à exécuter une application complète.
