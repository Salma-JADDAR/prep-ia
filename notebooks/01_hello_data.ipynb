# %%
import sys
print(sys.executable)
# Out:
# C:\Users\safiy\Desktop\prep-ia-salma\.venv\Scripts\python.exe

# %%
import sys
print("Python version:", sys.version)
print("Python path:", sys.executable)
# Out:
# Python version: 3.13.0 (tags/v3.13.0:60403a5, Oct  7 2024, 09:38:07) [MSC v.1941 64 bit (AMD64)]
# Python path: C:\Users\safiy\Desktop\prep-ia-salma\.venv\Scripts\python.exe

# %%
print("HELLO")
# Out:
# HELLO

# %%
a = 10
b = 5
choice = "1"

if choice == "1":
    print("Result =", a + b)

elif choice == "2":
    print("Result =", a - b)

elif choice == "3":
    print("Result =", a * b)

elif choice == "4":
    print("Result =", a / b)
# Out:
# Result = 15

# %%
a = float(input("Enter first number: "))

b = float(input("Enter second number: "))

choice = input("Enter your choice (1/2/3/4): ")

if choice == "1":

    print("Result =", a + b)

elif choice == "2":

    print("Result =", a - b)

elif choice == "3":

    print("Result =", a * b)

elif choice == "4":

    if b != 0:

        print("Result =", a / b)

    else:

        print("Error: division by zero")

else:

    print("Invalid choice")
# Out:
# Enter first number:  13
# Enter second number:  12
# Enter your choice (1/2/3/4):  3
# Result = 156.0

# %%
numbers = [1, 2, 3, 4, 5]

for n in numbers:
    print("Number =", n)
# Out:
# Number = 1
# Number = 2
# Number = 3
# Number = 4
# Number = 5

# %%
numbers = [1, 2, 3, 4, 5]

for n in numbers:
    print("Number =", n, "Square =", n*n)
# Out:
# Number = 1 Square = 1
# Number = 2 Square = 4
# Number = 3 Square = 9
# Number = 4 Square = 16
# Number = 5 Square = 25

# %%
## Réponses

### 1. Pourquoi utiliser un venv ?
# On isole les projets Python avec un venv pour éviter les conflits entre les bibliothèques,
# garder chaque projet indépendant et ne pas modifier le Python du système.

### 2. Installer des packages sans polluer le système
# On utilise pip dans un environnement virtuel (venv). 
# Les packages sont installés uniquement dans le projet sans affecter le Python global.

### 3. Lancer et exécuter des cellules dans un notebook
# On ouvre Jupyter Lab puis on exécute chaque cellule avec Shift + Entrée. Chaque cellule fonctionne indépendamment et affiche le résultat directement.

### 4. Différence entre script Python et notebook
# "Un script Python (.py) est un fichier exécuté d'un seul bloc, utilisé pour les programmes complets."
# Un notebook (.ipynb) est divisé en cellules, idéal pour l'apprentissage et l'analyse de données.
